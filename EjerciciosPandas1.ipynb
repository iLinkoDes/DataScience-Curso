# %%
import pandas as pd

# %%
serie_n = pd.Series(["10","20","10"])
serie_n
# Out:
# 0    10
# 1    20
# 2    10
# dtype: object

# %%
serie_c = pd.Series(["rojo","verde","azul"])
serie_c
# Out:
# 0     rojo
# 1    verde
# 2     azul
# dtype: object

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
