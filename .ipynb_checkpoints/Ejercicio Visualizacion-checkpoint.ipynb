# %%
import numpy as np
import pandas as pd

import matplotlib as mpl

df = pd.read_csv("data/datos_misteriosos.csv")

# %%
df
# Out:
#     dataset          x          y
# 0    clase1  55.384600  97.179500
# 1    clase1  51.538500  96.025600
# 2    clase1  46.153800  94.487200
# 3    clase1  42.820500  91.410300
# 4    clase1  40.769200  88.333300
# ..      ...        ...        ...
# 279  clase2  43.722551  19.077328
# 280  clase2  79.326078  52.900391
# 281  clase2  56.663974  87.940125
# 282  clase2  57.821789  90.693167
# 283  clase2  58.243172  92.104328
#
# [284 rows x 3 columns]

# %%
df.dtypes
# Out:
# dataset     object
# x          float64
# y          float64
# dtype: object

# %%
df[df.dataset=="clase1"].plot.scatter(x="x", y="y", alpha=1)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>
