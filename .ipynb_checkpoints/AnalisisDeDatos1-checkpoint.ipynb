# %%
import numpy as np
import pandas as pd

import matplotlib as mpl

df = pd.read_csv("data/vehiculos_original.csv")

# %%
df
# Out:
#              make                        model  year  displ  cylinders  \
# 0      AM General            DJ Po Vehicle 2WD  1984    2.5        4.0
# 1      AM General            DJ Po Vehicle 2WD  1984    2.5        4.0
# 2      AM General             FJ8c Post Office  1984    4.2        6.0
# 3      AM General             FJ8c Post Office  1984    4.2        6.0
# 4      AM General          Post Office DJ5 2WD  1985    2.5        4.0
# ...           ...                          ...   ...    ...        ...
# 38431       smart  fortwo electric drive coupe  2011    NaN        NaN
# 38432       smart  fortwo electric drive coupe  2013    NaN        NaN
# 38433       smart  fortwo electric drive coupe  2014    NaN        NaN
# 38434       smart  fortwo electric drive coupe  2015    NaN        NaN
# 38435       smart  fortwo electric drive coupe  2016    NaN        NaN
#
#                  trany             drive                       VClass  \
# 0      Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1      Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2      Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 3      Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 4      Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# ...                ...               ...                          ...
# 38431   Automatic (A1)  Rear-Wheel Drive                  Two Seaters
# 38432   Automatic (A1)  Rear-Wheel Drive                  Two Seaters
# 38433   Automatic (A1)  Rear-Wheel Drive                  Two Seaters
# 38434   Automatic (A1)  Rear-Wheel Drive                  Two Seaters
# 38435   Automatic (A1)  Rear-Wheel Drive                  Two Seaters
#
#           fuelType  comb08  co2TailpipeGpm
# 0          Regular      17      522.764706
# 1          Regular      17      522.764706
# 2          Regular      13      683.615385
# 3          Regular      13      683.615385
# 4          Regular      16      555.437500
# ...            ...     ...             ...
# 38431  Electricity      87        0.000000
# 38432  Electricity     107        0.000000
# 38433  Electricity     107        0.000000
# 38434  Electricity     107        0.000000
# 38435  Electricity     107        0.000000
#
# [38436 rows x 11 columns]

# %%
df = df.rename(columns={
    "cylinders":"cilindros",
    "trany":"transmision",
    "make":"fabricante",
    "model":"modelo",
    "displ":"desplazamiento",#volumen de desplazamiento del motor
    "drive":"traccion",
    "VClass":"clase",
    "fuelType":"combustible",
    "comb08":"consumo",
    "co2TailpipeGpm":"c02"
})
df.head()
# Out:
#    fabricante               modelo  year  desplazamiento  cilindros  \
# 0  AM General    DJ Po Vehicle 2WD  1984             2.5        4.0
# 1  AM General    DJ Po Vehicle 2WD  1984             2.5        4.0
# 2  AM General     FJ8c Post Office  1984             4.2        6.0
# 3  AM General     FJ8c Post Office  1984             4.2        6.0
# 4  AM General  Post Office DJ5 2WD  1985             2.5        4.0
#
#        transmision          traccion                        clase combustible  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD     Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD     Regular
# 2  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD     Regular
# 3  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD     Regular
# 4  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD     Regular
#
#    consumo         c02
# 0       17  522.764706
# 1       17  522.764706
# 2       13  683.615385
# 3       13  683.615385
# 4       16  555.437500

# %%
df.dtypes
# Out:
# fabricante         object
# modelo             object
# year                int64
# desplazamiento    float64
# cilindros         float64
# transmision        object
# traccion           object
# clase              object
# combustible        object
# consumo             int64
# c02               float64
# dtype: object

# %%
df.to_csv("data/vehiculos_procesadores.csv", index=False)
